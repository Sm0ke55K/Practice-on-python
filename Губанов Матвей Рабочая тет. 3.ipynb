# %% [markdown]
# # Губанов Матвей Рабочая тетрадь №3  БББО-08-20

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Задача 1.3.1

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

ax = plt.figure().add_subplot(111, projection ='3d')
x = np.array([1, 4, 0])
y = np.array([3.3, 5,7])
z = np.array([0, 2, 1])
w = np.array([1, 3, 7])
ax.scatter(1, 4, 0)
ax.scatter(3.3, 5 ,7)
ax.scatter(0, 2, 1)
ax.scatter(1, 3 ,7)
plt.show()

print(
(np.linalg.norm(x-y)),'\n',
(np.linalg.norm(x-y) ** 2),'\n',
(np.linalg.norm(x-y, ord=np.inf)),'\n',
(np.linalg.norm(x-y,ord=1)),'\n')

print(
(np.linalg.norm(x-z)),'\n',
(np.linalg.norm(x-z) ** 2),'\n',
(np.linalg.norm(x-z, ord=np.inf)),'\n',
(np.linalg.norm(x-z,ord=1)),'\n')

print(
(np.linalg.norm(x-w)),'\n',
(np.linalg.norm(x-w) ** 2),'\n',
(np.linalg.norm(x-w, ord=np.inf)),'\n',
(np.linalg.norm(x-w,ord=1)),'\n')

print(
(np.linalg.norm(y-z)),'\n',
(np.linalg.norm(y-z) ** 2),'\n',
(np.linalg.norm(y-z, ord=np.inf)),'\n',
(np.linalg.norm(y-z,ord=1)),'\n')

print(
(np.linalg.norm(y-w)),'\n',
(np.linalg.norm(y-w) ** 2),'\n',
(np.linalg.norm(y-w, ord=np.inf)),'\n',
(np.linalg.norm(y-w,ord=1)),'\n')

print(
(np.linalg.norm(z-w)),'\n',
(np.linalg.norm(z-w) ** 2),'\n',
(np.linalg.norm(z-w, ord=np.inf)),'\n',
(np.linalg.norm(z-w,ord=1)))
# Out:
# 7.4357245780085215
#  55.290000000000006
#  7.0
#  10.3
#
# 2.449489742783178
#  5.999999999999999
#  2.0
#  4.0
#
# 7.0710678118654755
#  50.00000000000001
#  7.0
#  8.0
#
# 7.475961476626267
#  55.89
#  6.0
#  12.3
#
# 3.047950130825634
#  9.29
#  2.3
#  4.3
#
# 6.164414002968976
#  37.99999999999999
#  6.0
#  8.0

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import seaborn as sns

iris = sns.load_dataset('iris')
iris

X_train, X_test, y_train, y_test = train_test_split(  ##train - производится настройка (оптимизация параметров). test - выборка, по которой оценивается качество построенной модели.
    iris.iloc[:, :-1],  ## Все колонки кроме последней
    iris.iloc[:, -1],  ## Последнюю в целевую переменную
    test_size = 0.15  ## Текстовая выборка
)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
    
X_train.head()
y_train.head()
    
model = KNeighborsClassifier(n_neighbors=10)  ##  Обучим метод 10 ближ. сосед.
model.fit(X_train, y_train)

y_pred = model.predict(X_test)  ##  Получим предсказания модели
y_pred

plt.figure(figsize=(10, 7))
sns.scatterplot(x='petal_width', y='petal_length', data=iris, hue='species', s=70)
plt.xlabel('Длина лепестка, см')
plt.ylabel('Ширина лепестка,см ')
plt.legend(loc=2)
plt.grid()

for i in range(len(y_test)):
    if np.array(y_test)[i] != y_pred[i]:
        plt.scatter(X_test.iloc[i, 3], X_test.iloc[i, 2], color='red', s=150)

from sklearn.metrics import accuracy_score
print(f'accurace: {accuracy_score(y_test, y_pred) :.3}')
# Out:
# accurace: 0.913

# %% [markdown]
# # Задача 3.3.2

# %%
import pandas as pd

dataframe = pd.DataFrame({"Признаки человека": ["Общительность","Харизматичность","Интелект","Интелект","Общительность","Общительность"]})
scale_mapper = {"Интелект":1,"Общительность":2,"Харизматичность":3}

dataframe["Признаки человека"].replace(scale_mapper)
# Out:
# 0    2
# 1    3
# 2    1
# 3    1
# 4    2
# 5    2
# Name: Признаки человека, dtype: int64

# %%
from sklearn.feature_extraction import DictVectorizer

data_dict = [{"IQ": 99, "цвет волос": 3},
             {"цвет глаз": 5,"внешность": 6},
             {"рост": 182, "вес": 75},
             {"возраст": 19, "пол": 1}]

dictvectorizer = DictVectorizer(sparse=False)
features = dictvectorizer.fit_transform(data_dict)
features
# Out:
# array([[ 99.,   0.,   0.,   0.,   0.,   0.,   3.,   0.],
#        [  0.,   0.,   6.,   0.,   0.,   0.,   0.,   5.],
#        [  0.,  75.,   0.,   0.,   0., 182.,   0.,   0.],
#        [  0.,   0.,   0.,  19.,   1.,   0.,   0.,   0.]])
